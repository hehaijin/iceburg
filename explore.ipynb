# %%
import tensorflow as tf
import os.path as path
import numpy as np
import pandas as pd
import json
import matplotlib.pyplot as plt

# %%
cd C:\\Users\\Haijin\\DataScience\\iceberg
# Out:
# C:\Users\Haijin\DataScience\iceberg

# %%
datapath='.\data\processed'

# %%
with open(path.join(datapath, 'train.json')) as trainfile:
    data=pd.read_json(trainfile)
    print(len(data.iloc[0]["band_1"]))
    iceburg=0
    for i in range(10):
        row=data.iloc[i]
        pic1=np.reshape(row["band_1"],(75,75))
        pic2=np.reshape(row["band_2"],(75,75))
        plt.subplot(10,2,i*2+1)
        plt.imshow(pic1)
        plt.subplot(10,2,i*2+2)
        plt.imshow(pic2)
        plt.show()
# Out:
# 5625
